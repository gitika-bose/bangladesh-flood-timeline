# %% [markdown]
# ### Imports

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, ParameterGrid
from nltk.tokenize import word_tokenize
from sklearn.utils import shuffle
import pandas as pd
from copy import deepcopy
import os
import json
import random
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from functions import load_data, query_dataframe

# %% [markdown]
# ### Define Variables

# %%
global_shuffle_seed = 32
global_debug=False
global_override=False

# %% [markdown]
# ### Load Data

# %%
result, clf_result = {}, {}
df_data = load_data()

# %%
data_true = query_dataframe(df_data, {'is_flood':True})
data_false = query_dataframe(df_data, {'is_flood':False})
print('Total:',len(df_data),'True:',len(data_true), 'False:',len(data_false))
# Out:
# Total: 608 True: 63 False: 542

# %%
def make_data_ratio(df_data, ratio=0, shuffle_seed=4, debug=False, save_folder=None, load_folder=None, override=False, file_prefix=''):
    save_file, load_file=None, None
    if save_folder: save_file = os.path.join(save_folder,file_prefix+'all.json') if ratio==0 else os.path.join(save_folder,file_prefix+'1-{}.json'.format(ratio))
    if load_folder: load_file = os.path.join(load_folder,file_prefix+'all.json') if ratio==0 else os.path.join(load_folder,file_prefix+'1-{}.json'.format(ratio))

    if not override and load_file and os.path.isfile(load_file):
        if debug: print('loaded',load_file)
        js = json.load(open(load_file))
        train_rdf = pd.DataFrame(js['train'])
        test_rdf = pd.DataFrame(js['test'])
        return {'train':train_rdf, 'test':test_rdf}
    new_df = df_data.sample(n=len(df_data), random_state=shuffle_seed).reset_index(drop=True)
    
    if not ratio: total_data = new_df
    else:
        true_data = [dict(row[1]) for row in new_df.iterrows() if row[1]['is_flood']]
        false_data = [dict(row[1]) for row in new_df.iterrows() if not row[1]['is_flood']]
        true_nums = len(true_data)
        false_nums = min(true_nums * ratio, len(false_data))
        if false_nums==len(false_data) and debug: print('All false data points taken')
        total_data = true_data + [false_data[i] for i in range(0,false_nums)]
    train, test = train_test_split(total_data, test_size=0.2, random_state=shuffle_seed)
    train_rdf = pd.DataFrame(train)
    test_rdf = pd.DataFrame(test)
    if debug: print('data-ratio',ratio)

    if save_file:
        train_json = train_rdf.to_json(orient='records')
        test_json = test_rdf.to_json(orient='records')
        json.dump({'train':json.loads(train_json), 'test':json.loads(test_json)}, open(save_file,'w'), indent=2)
    return {'train':train_rdf, 'test':test_rdf}

# %%
df_data = load_data()
result, clf_result = {}, {}
save_data_folder = 'data_splits/'
load_data_folder = 'data_splits/'
if not os.path.isdir(save_data_folder): os.mkdir(save_data_folder)
debug=global_debug or True
override=global_override or False
data = {
        'all': make_data_ratio(df_data, save_folder=save_data_folder, load_folder=load_data_folder, 
                               debug=debug, shuffle_seed=global_shuffle_seed, override=override),
        '1:1': make_data_ratio(df_data,1, save_folder=save_data_folder, load_folder=load_data_folder, 
                               debug=debug, shuffle_seed=global_shuffle_seed, override=override),
        '1:2': make_data_ratio(df_data,2, save_folder=save_data_folder, load_folder=load_data_folder, 
                               debug=debug, shuffle_seed=global_shuffle_seed, override=override),
        '1:3': make_data_ratio(df_data,3, save_folder=save_data_folder, load_folder=load_data_folder, 
                               debug=debug, shuffle_seed=global_shuffle_seed, override=override),
        '1:5': make_data_ratio(df_data,5, save_folder=save_data_folder, load_folder=load_data_folder, 
                               debug=debug, shuffle_seed=global_shuffle_seed, override=override)
}
# Out:
# loaded data_splits/all.json
# loaded data_splits/1-1.json
# loaded data_splits/1-2.json
# loaded data_splits/1-3.json
# loaded data_splits/1-5.json

# %% [markdown]
# ### Classifier

# %%
def make_data(vect_fit, ratio):
    train, test = ratio.get('train',None), ratio.get('test',None)
    if train is None or test is None: raise Exception('Train or Test data not found')
    all_X = list(train['text']) + list(test['text'])
    
    vect = vect_fit.fit(all_X)
    trainX, testX = vect.transform(list(train['text'])), vect.transform((test['text']))
    trainY, testY = [1 if t else 0 for t in train['is_flood']], [1 if t else 0 for t in test['is_flood']]
    return trainX, testX, trainY, testY, vect

# %%
def run_classifier(clf, trainX, testX, trainY, testY):
    clf_fit = clf.fit(trainX, trainY)
    clf_pred = clf_fit.predict(testX)
    clf_acc = accuracy_score(testY, clf_pred)
    return clf_fit, clf_pred, clf_acc

# %%
def get_method(main_d, name):
    if name not in main_d: raise Exception('Cannot find classifier/feature_extractor name in parameter dictionary')
    d = main_d[name]
    method = d.get('method',None)
    base_method = d.get('base_method',None)
    if method and base_method: raise Exception('Cannot have method and base method both.')
    if not method and not base_method: raise Exception('Unable to parse the method from classifier/feature_extractor')
    params = d.get('params',None)
    if method:
        if params: return method, params
        else: return method, None
    if base_method:
        prev_method, prev_params = get_method(main_d, base_method)
        if params:
            for k,v in params.items(): prev_params[k] = v
        return prev_method, prev_params

def make_method(main_d, name, override_params={}):
    method, params = get_method(main_d, name)[:]
    if override_params:
        for k,v in override_params.items(): params[k] = v
    if params: return method(**params)
    else: return method()

# %%
def run_grid(grid, data, feature_extract, classifiers, clf_result, result, 
             debug=False, override=False, save_folder=None, load_folder=None, file_prefix=''):
    save_clf_result = {}
    if load_folder:
        res_file = os.path.join(load_folder,file_prefix+'clf_result.json')
        clf_res_file = os.path.join(load_folder,file_prefix+'result.json')
        if os.path.isfile(res_file): clf_result=json.load(open(res_file))
        if os.path.isfile(clf_res_file): result=json.load(open(clf_res_file))
        if os.path.isfile(res_file) and os.path.isfile(clf_res_file) and debug: print('loaded result')
    
    if override:
        clf_result, result = {}, {}
        if debug: print('OVERRIDE')
    for g in list(grid):
        try:
            data_name = g.get('data',None)
            feature_name = g.get('feature_extract',None)
            clf_name = g.get('classifier', None)
            if not feature_name or not clf_name or not data_name:
                raise Exception('Data Ratio, Feature Extract and Classifier Name required')
            result_key = data_name + '-' + feature_name + '-' + clf_name
            if result.get(result_key): continue
            if debug: print('Data Ratio:',data_name, '  Feature Name:', \
                            feature_name, '  Clasifier Name:',clf_name, '  Key:',result_key)
                
            ratio = data.get(data_name, None)
            if ratio is None: raise Exception('Cannot find data ratio')
            
            feature = make_method(feature_extract, feature_name)
            trainX, testX, trainY, testY, feature2 = make_data(feature, ratio)
            
            clf = make_method(classifiers, clf_name)
            clf_fit, clf_pred, clf_acc = run_classifier(clf, trainX, testX, trainY, testY)
            
            result[result_key] = {
                'data_ratio': data_name,
                'feature_extract': feature_name,
                'classifier': clf_name,
                'accuracy': clf_acc
            }
            
            clf_result[result_key] = {
                'data_ratio': data_name,
                'feature_extract': feature_name,
                'classifier': clf_name,
                'clf': clf_fit,
                'feature': feature2,
                'predict': clf_pred
            }
            
            save_clf_result[result_key] = {
                'data_ratio': data_name,
                'feature_extract': feature_name,
                'classifier': clf_name,
                'predict': clf_pred.tolist()
            }  
        except Exception as e:
            print('Error:',e)
            continue
    if save_folder:
        json.dump(save_clf_result, open(os.path.join(load_folder,file_prefix+'clf_result.json'),'w'), indent=2)
        json.dump(result, open(os.path.join(load_folder,file_prefix+'result.json'),'w'), indent=2)
    return clf_result, result

# %%
def parse_result(result, accuracy_threshold=None):
    keys = list(result.keys())
    temp_df = pd.DataFrame(list(result.values()))
    temp_df['keys'] = keys
    data_vals = list(set(list(temp_df['data_ratio'])))
    if 'all' in data_vals:
        data_vals.remove('all')
        data_vals.sort(key=lambda x:int(x.split(':')[1]))
        data_vals.append('all')
    else:
        data_vals.sort(key=lambda x:int(x.split(':')[1]))
    for d in data_vals:
        if accuracy_threshold:
            new_df = temp_df.loc[temp_df['data_ratio']==d]
            new_df = new_df.loc[new_df['accuracy']>accuracy_threshold] \
                            .drop('data_ratio', axis=1) \
                            .set_index('feature_extract').sort_index()
        else:
            new_df = temp_df.loc[temp_df['data_ratio']==d] \
                            .drop('data_ratio', axis=1) \
                            .set_index('feature_extract').sort_index()
        print('Data Ratio:',d)
        print(new_df.to_markdown())
        print()

# %%
def compare_result(clf_result, data, method_name, conf_matrix=True):
    if method_name not in clf_result: raise Exception('Cannot find method')
    res = clf_result[method_name]
    new_df = data[res['data_ratio']]['test']
    actual = list(new_df['is_flood'])
    new_df['predict'] = res['predict']
    if conf_matrix: print(confusion_matrix(actual, res['predict']))
    return new_df

# %%
feature_extract = {
    'CountVect': {
        'classifier_type': 'Count Vectorizer',
        'method': CountVectorizer,
        'params': {
            'tokenizer': word_tokenize,
            'stop_words': 'english'
        }
    },
    'CountVect-min_df5':{
        'base_method': 'CountVect',
        'params':{
            'min_df': 5
        }
    },
    'CountVect-min_df10':{
        'base_method': 'CountVect',
        'params':{
            'min_df': 10
        }
    },
    'TFIDF': {
        'classifier_type': 'TFIDF',
        'method': TfidfVectorizer,
        'params': {
            'tokenizer': word_tokenize,
            'stop_words': 'english'
        }
    },
    'TFIDF-min_df5':{
        'base_method': 'TFIDF',
        'params':{
            'min_df': 5
        }
    },
    'TFIDF-min_df10':{
        'base_method': 'TFIDF',
        'params':{
            'min_df': 10
        }
    },
}

classifiers = {
    'DecisionTree': {
        'classifier_type':'Decision Tree',
        'method': DecisionTreeClassifier,
    },
    'RandomForest': {
        'classifier_type':'Random Forest ',
        'method': RandomForestClassifier,
    },
    'LinearSVC': {
        'classifier_type': 'Linear SVC',
        'method': LinearSVC
    }
}

grid_parameters = {
    'data': list(data.keys()),
    'feature_extract': list(feature_extract.keys()),
    'classifier': list(classifiers.keys()),
}
grid = ParameterGrid(grid_parameters)

# %%
override=global_override or False
debug=True
save_results_folder = 'results/'
load_results_folder = 'results/'
if not os.path.isdir(save_results_folder): os.mkdir(save_results_folder)
clf_result, result = run_grid(grid, data, feature_extract, classifiers, clf_result, result, 
                              debug=debug, override=override, save_folder=save_results_folder, 
                             load_folder=load_results_folder)
# Out:
# loaded result

# %%
parse_result(result)
# Out:
# Data Ratio: 1:1
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | DecisionTree |   0.769231 | 1:1-CountVect-DecisionTree          |
# | CountVect          | LinearSVC    |   0.730769 | 1:1-CountVect-LinearSVC             |
# | CountVect          | RandomForest |   0.961538 | 1:1-CountVect-RandomForest          |
# | CountVect-min_df10 | LinearSVC    |   0.730769 | 1:1-CountVect-min_df10-LinearSVC    |
# | CountVect-min_df10 | RandomForest |   0.961538 | 1:1-CountVect-min_df10-RandomForest |
# | CountVect-min_df10 | DecisionTree |   0.923077 | 1:1-CountVect-min_df10-DecisionTree |
# | CountVect-min_df5  | RandomForest |   0.923077 | 1:1-CountVect-min_df5-RandomForest  |
# | CountVect-min_df5  | LinearSVC    |   0.730769 | 1:1-CountVect-min_df5-LinearSVC     |
# | CountVect-min_df5  | DecisionTree |   0.769231 | 1:1-CountVect-min_df5-DecisionTree  |
# | TFIDF              | DecisionTree |   0.846154 | 1:1-TFIDF-DecisionTree              |
# | TFIDF              | RandomForest |   0.923077 | 1:1-TFIDF-RandomForest              |
# | TFIDF              | LinearSVC    |   0.884615 | 1:1-TFIDF-LinearSVC                 |
# | TFIDF-min_df10     | DecisionTree |   0.769231 | 1:1-TFIDF-min_df10-DecisionTree     |
# | TFIDF-min_df10     | RandomForest |   0.923077 | 1:1-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df10     | LinearSVC    |   0.884615 | 1:1-TFIDF-min_df10-LinearSVC        |
# | TFIDF-min_df5      | LinearSVC    |   0.884615 | 1:1-TFIDF-min_df5-LinearSVC         |
# | TFIDF-min_df5      | RandomForest |   0.961538 | 1:1-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | DecisionTree |   0.807692 | 1:1-TFIDF-min_df5-DecisionTree      |
#
# Data Ratio: 1:2
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | DecisionTree |   0.921053 | 1:2-CountVect-DecisionTree          |
# | CountVect          | LinearSVC    |   0.894737 | 1:2-CountVect-LinearSVC             |
# | CountVect          | RandomForest |   0.894737 | 1:2-CountVect-RandomForest          |
# | CountVect-min_df10 | LinearSVC    |   0.894737 | 1:2-CountVect-min_df10-LinearSVC    |
# | CountVect-min_df10 | RandomForest |   0.894737 | 1:2-CountVect-min_df10-RandomForest |
# | CountVect-min_df10 | DecisionTree |   0.894737 | 1:2-CountVect-min_df10-DecisionTree |
# | CountVect-min_df5  | RandomForest |   0.868421 | 1:2-CountVect-min_df5-RandomForest  |
# | CountVect-min_df5  | LinearSVC    |   0.921053 | 1:2-CountVect-min_df5-LinearSVC     |
# | CountVect-min_df5  | DecisionTree |   0.894737 | 1:2-CountVect-min_df5-DecisionTree  |
# | TFIDF              | DecisionTree |   0.684211 | 1:2-TFIDF-DecisionTree              |
# | TFIDF              | RandomForest |   0.921053 | 1:2-TFIDF-RandomForest              |
# | TFIDF              | LinearSVC    |   0.921053 | 1:2-TFIDF-LinearSVC                 |
# | TFIDF-min_df10     | DecisionTree |   0.815789 | 1:2-TFIDF-min_df10-DecisionTree     |
# | TFIDF-min_df10     | RandomForest |   0.947368 | 1:2-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df10     | LinearSVC    |   0.921053 | 1:2-TFIDF-min_df10-LinearSVC        |
# | TFIDF-min_df5      | LinearSVC    |   0.921053 | 1:2-TFIDF-min_df5-LinearSVC         |
# | TFIDF-min_df5      | RandomForest |   0.947368 | 1:2-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | DecisionTree |   0.815789 | 1:2-TFIDF-min_df5-DecisionTree      |
#
# Data Ratio: 1:3
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | DecisionTree |   0.862745 | 1:3-CountVect-DecisionTree          |
# | CountVect          | LinearSVC    |   0.882353 | 1:3-CountVect-LinearSVC             |
# | CountVect          | RandomForest |   0.960784 | 1:3-CountVect-RandomForest          |
# | CountVect-min_df10 | LinearSVC    |   0.882353 | 1:3-CountVect-min_df10-LinearSVC    |
# | CountVect-min_df10 | RandomForest |   0.941176 | 1:3-CountVect-min_df10-RandomForest |
# | CountVect-min_df10 | DecisionTree |   0.823529 | 1:3-CountVect-min_df10-DecisionTree |
# | CountVect-min_df5  | RandomForest |   0.901961 | 1:3-CountVect-min_df5-RandomForest  |
# | CountVect-min_df5  | LinearSVC    |   0.882353 | 1:3-CountVect-min_df5-LinearSVC     |
# | CountVect-min_df5  | DecisionTree |   0.843137 | 1:3-CountVect-min_df5-DecisionTree  |
# | TFIDF              | DecisionTree |   0.882353 | 1:3-TFIDF-DecisionTree              |
# | TFIDF              | RandomForest |   0.941176 | 1:3-TFIDF-RandomForest              |
# | TFIDF              | LinearSVC    |   0.901961 | 1:3-TFIDF-LinearSVC                 |
# | TFIDF-min_df10     | DecisionTree |   0.882353 | 1:3-TFIDF-min_df10-DecisionTree     |
# | TFIDF-min_df10     | RandomForest |   0.941176 | 1:3-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df10     | LinearSVC    |   0.901961 | 1:3-TFIDF-min_df10-LinearSVC        |
# | TFIDF-min_df5      | LinearSVC    |   0.921569 | 1:3-TFIDF-min_df5-LinearSVC         |
# | TFIDF-min_df5      | RandomForest |   0.960784 | 1:3-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | DecisionTree |   0.862745 | 1:3-TFIDF-min_df5-DecisionTree      |
#
# Data Ratio: 1:5
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | DecisionTree |   0.868421 | 1:5-CountVect-DecisionTree          |
# | CountVect          | LinearSVC    |   0.934211 | 1:5-CountVect-LinearSVC             |
# | CountVect          | RandomForest |   0.881579 | 1:5-CountVect-RandomForest          |
# | CountVect-min_df10 | LinearSVC    |   0.934211 | 1:5-CountVect-min_df10-LinearSVC    |
# | CountVect-min_df10 | RandomForest |   0.855263 | 1:5-CountVect-min_df10-RandomForest |
# | CountVect-min_df10 | DecisionTree |   0.855263 | 1:5-CountVect-min_df10-DecisionTree |
# | CountVect-min_df5  | RandomForest |   0.868421 | 1:5-CountVect-min_df5-RandomForest  |
# | CountVect-min_df5  | LinearSVC    |   0.921053 | 1:5-CountVect-min_df5-LinearSVC     |
# | CountVect-min_df5  | DecisionTree |   0.934211 | 1:5-CountVect-min_df5-DecisionTree  |
# | TFIDF              | DecisionTree |   0.855263 | 1:5-TFIDF-DecisionTree              |
# | TFIDF              | RandomForest |   0.894737 | 1:5-TFIDF-RandomForest              |
# | TFIDF              | LinearSVC    |   0.947368 | 1:5-TFIDF-LinearSVC                 |
# | TFIDF-min_df10     | DecisionTree |   0.855263 | 1:5-TFIDF-min_df10-DecisionTree     |
# | TFIDF-min_df10     | RandomForest |   0.881579 | 1:5-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df10     | LinearSVC    |   0.947368 | 1:5-TFIDF-min_df10-LinearSVC        |
# | TFIDF-min_df5      | LinearSVC    |   0.947368 | 1:5-TFIDF-min_df5-LinearSVC         |
# | TFIDF-min_df5      | RandomForest |   0.881579 | 1:5-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | DecisionTree |   0.815789 | 1:5-TFIDF-min_df5-DecisionTree      |
#
# Data Ratio: all
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | DecisionTree |   0.885246 | all-CountVect-DecisionTree          |
# | CountVect          | LinearSVC    |   0.942623 | all-CountVect-LinearSVC             |
# | CountVect          | RandomForest |   0.885246 | all-CountVect-RandomForest          |
# | CountVect-min_df10 | LinearSVC    |   0.942623 | all-CountVect-min_df10-LinearSVC    |
# | CountVect-min_df10 | RandomForest |   0.893443 | all-CountVect-min_df10-RandomForest |
# | CountVect-min_df10 | DecisionTree |   0.901639 | all-CountVect-min_df10-DecisionTree |
# | CountVect-min_df5  | RandomForest |   0.877049 | all-CountVect-min_df5-RandomForest  |
# | CountVect-min_df5  | LinearSVC    |   0.942623 | all-CountVect-min_df5-LinearSVC     |
# | CountVect-min_df5  | DecisionTree |   0.844262 | all-CountVect-min_df5-DecisionTree  |
# | TFIDF              | DecisionTree |   0.893443 | all-TFIDF-DecisionTree              |
# | TFIDF              | RandomForest |   0.893443 | all-TFIDF-RandomForest              |
# | TFIDF              | LinearSVC    |   0.959016 | all-TFIDF-LinearSVC                 |
# | TFIDF-min_df10     | DecisionTree |   0.893443 | all-TFIDF-min_df10-DecisionTree     |
# | TFIDF-min_df10     | RandomForest |   0.901639 | all-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df10     | LinearSVC    |   0.959016 | all-TFIDF-min_df10-LinearSVC        |
# | TFIDF-min_df5      | LinearSVC    |   0.95082  | all-TFIDF-min_df5-LinearSVC         |
# | TFIDF-min_df5      | RandomForest |   0.885246 | all-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | DecisionTree |   0.918033 | all-TFIDF-min_df5-DecisionTree      |

# %%
parse_result(result, 0.92)
# Out:
# Data Ratio: 1:1
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | RandomForest |   0.961538 | 1:1-CountVect-RandomForest          |
# | CountVect-min_df10 | DecisionTree |   0.923077 | 1:1-CountVect-min_df10-DecisionTree |
# | CountVect-min_df10 | RandomForest |   0.961538 | 1:1-CountVect-min_df10-RandomForest |
# | CountVect-min_df5  | RandomForest |   0.923077 | 1:1-CountVect-min_df5-RandomForest  |
# | TFIDF              | RandomForest |   0.923077 | 1:1-TFIDF-RandomForest              |
# | TFIDF-min_df10     | RandomForest |   0.923077 | 1:1-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df5      | RandomForest |   0.961538 | 1:1-TFIDF-min_df5-RandomForest      |
#
# Data Ratio: 1:2
# | feature_extract   | classifier   |   accuracy | keys                            |
# |:------------------|:-------------|-----------:|:--------------------------------|
# | CountVect         | DecisionTree |   0.921053 | 1:2-CountVect-DecisionTree      |
# | CountVect-min_df5 | LinearSVC    |   0.921053 | 1:2-CountVect-min_df5-LinearSVC |
# | TFIDF             | RandomForest |   0.921053 | 1:2-TFIDF-RandomForest          |
# | TFIDF             | LinearSVC    |   0.921053 | 1:2-TFIDF-LinearSVC             |
# | TFIDF-min_df10    | RandomForest |   0.947368 | 1:2-TFIDF-min_df10-RandomForest |
# | TFIDF-min_df10    | LinearSVC    |   0.921053 | 1:2-TFIDF-min_df10-LinearSVC    |
# | TFIDF-min_df5     | RandomForest |   0.947368 | 1:2-TFIDF-min_df5-RandomForest  |
# | TFIDF-min_df5     | LinearSVC    |   0.921053 | 1:2-TFIDF-min_df5-LinearSVC     |
#
# Data Ratio: 1:3
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | RandomForest |   0.960784 | 1:3-CountVect-RandomForest          |
# | CountVect-min_df10 | RandomForest |   0.941176 | 1:3-CountVect-min_df10-RandomForest |
# | TFIDF              | RandomForest |   0.941176 | 1:3-TFIDF-RandomForest              |
# | TFIDF-min_df10     | RandomForest |   0.941176 | 1:3-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df5      | RandomForest |   0.960784 | 1:3-TFIDF-min_df5-RandomForest      |
# | TFIDF-min_df5      | LinearSVC    |   0.921569 | 1:3-TFIDF-min_df5-LinearSVC         |
#
# Data Ratio: 1:5
# | feature_extract    | classifier   |   accuracy | keys                               |
# |:-------------------|:-------------|-----------:|:-----------------------------------|
# | CountVect          | LinearSVC    |   0.934211 | 1:5-CountVect-LinearSVC            |
# | CountVect-min_df10 | LinearSVC    |   0.934211 | 1:5-CountVect-min_df10-LinearSVC   |
# | CountVect-min_df5  | DecisionTree |   0.934211 | 1:5-CountVect-min_df5-DecisionTree |
# | CountVect-min_df5  | LinearSVC    |   0.921053 | 1:5-CountVect-min_df5-LinearSVC    |
# | TFIDF              | LinearSVC    |   0.947368 | 1:5-TFIDF-LinearSVC                |
# | TFIDF-min_df10     | LinearSVC    |   0.947368 | 1:5-TFIDF-min_df10-LinearSVC       |
# | TFIDF-min_df5      | LinearSVC    |   0.947368 | 1:5-TFIDF-min_df5-LinearSVC        |
#
# Data Ratio: all
# | feature_extract    | classifier   |   accuracy | keys                             |
# |:-------------------|:-------------|-----------:|:---------------------------------|
# | CountVect          | LinearSVC    |   0.942623 | all-CountVect-LinearSVC          |
# | CountVect-min_df10 | LinearSVC    |   0.942623 | all-CountVect-min_df10-LinearSVC |
# | CountVect-min_df5  | LinearSVC    |   0.942623 | all-CountVect-min_df5-LinearSVC  |
# | TFIDF              | LinearSVC    |   0.959016 | all-TFIDF-LinearSVC              |
# | TFIDF-min_df10     | LinearSVC    |   0.959016 | all-TFIDF-min_df10-LinearSVC     |
# | TFIDF-min_df5      | LinearSVC    |   0.95082  | all-TFIDF-min_df5-LinearSVC      |

# %%
compare_result(clf_result, data, '1:1-TFIDF-min_df5-RandomForest')
# Out:
# [[11  0]
#  [ 1 14]]
#                                   doc_id  \
# 0                                   None
# 1                                   None
# 2   83244a0f-4ba2-4097-ad62-8f0bf3852cb9
# 3   566e61fe-266f-42ca-8923-338a55b4ee5c
# 4   ae67dbcb-80eb-4fbf-a478-5a2ec8bc445c
# 5                                   None
# 6   1c428e80-a9d1-4a26-9369-f4930f4858a9
# 7                                   None
# 8                                   None
# 9   c27d553b-857a-4442-b2e6-c65d2723cbdf
# 10  c550fe06-87e9-438b-8e4b-23864187b4da
# 11  b48dfab9-5c63-4e6f-b00b-8d3d72ea8c93
# 12  b1c74ccc-9861-4a38-abe4-abb65a447de0
# 13  f4182e23-bcd2-4627-b5ee-6284ac4a2eac
# 14  ab05f873-313a-4abe-beed-762e797871e7
# 15  267e797c-940b-47d0-98bc-eb56e589b69c
# 16  17d15ead-a086-4fa5-ae02-ce76c52d1284
# 17                                  None
# 18                                  None
# 19  20d315c3-7597-4fa7-9764-19047439610e
# 20  b4762d6c-c102-4913-8661-435be6299571
# 21  3e0c6942-1f63-4675-b248-8a4f628c8f92
# 22  f70a929b-10f5-4cd2-b29c-b2d5723cf22f
# 23                                  None
# 24  b1869fff-db3f-482c-885b-27a8957b5934
# 25                                  None
#
#                                              filename  is_flood  \
# 0   a4fskUJKFHYektuFIx5ZETIrjRma-1987_acde84fb87df...      True
# 1   araLJi81IPOJ7f9GMEz9YK7sy3uS-1989_79269b1b983f...     False
# 2   arseC9cfb.zjk0gJlJCv.91O1d4K-dhakaTribune_data...      True
# 3   a7E2o724RaTj5PcoX.vKCdTk7IrW-dhakaTribune_data...     False
# 4   aeBu7Vd4bXNRkEEGmvQ7aFG4oS0C-theDailyStar_data...     False
# 5   a7dCFrpObpJaEgRbcD8kZSrysfLO-1988_1627fbc1b3da...      True
# 6   aE92tOgn3iGqpz4z0TMtBhPeuoAi-theDailyStar_data...      True
# 7   au37fJC_PlfQaFbYQ3YOYEZivxYu-1988_4730bf7e1391...      True
# 8   akxy7trkrzXGd.GjQ6hQhCEUdJXy-1988_0dd4a99cd1a7...      True
# 9   akoXaeBgB_DDXJTULUMMZDCjkKYO-dhakaTribune_data...      True
# 10  acS5MY7H_bIADXZdzj3sD0s_BP4e-dhakaTribune_data...      True
# 11  avxaw2QVI4hPSjLwIE3KnA7mvgv8-dhakaTribune_data...     False
# 12  a3v4BLK45rJYByAZfNS37Ep5OmZm-dhakaTribune_data...     False
# 13  a.Hq4zFA1jCAtcK2PEtWUG2fkzgm-dhakaTribune_data...     False
# 14  aZYxEqe7zRy12pJ7jIHfH6Pb6iI8-dhakaTribune_data...     False
# 15  a0pp9ePTufPP0HZKYtnwXB0MgM1G-theDailyStar_data...     False
# 16  aRqZxEoMTzuWq2HIyozeWFN3qJ3C-dhakaTribune_data...      True
# 17  aBgxCuAuJWvAdrSKjAbmLkNYTh.y-1988_13f816258641...      True
# 18  awZ8Qm3X_auMx_x66F6uhdO0fvP4-1988_aecd9390d0d4...      True
# 19  a_D6ELbZrBbQhVgUaeu5YNLCSWz8-theDailyStar_data...     False
# 20  adGVzv6170i4ucUMtz4nePG8_BIG-theDailyStar_data...      True
# 21  aeI7LOZfRAzzSBH8zW_J1Ulcy7d8-theDailyStar_data...     False
# 22  aWMw_7zcnRH.lKoz3.jPnKFESixu-theDailyStar_data...      True
# 23  au7tdyMDY7zPUtBhXHvQKowIjYAO-1987_524bfe0ec76a...      True
# 24  aKd7u7PVkOKwuXyBr_LGhsFpXQH8-dhakaTribune_data...     False
# 25  apPTuxcVkWQGrsxPouOqmOEOEOkK-1988_2ad8c990817a...      True
#
#     is_bangladesh  flood_related  flood_climatechange      newspaper  \
# 0            True           True                False       ny_times
# 1           False          False                False       ny_times
# 2            True           True                False  dhaka_tribune
# 3            True          False                False  dhaka_tribune
# 4            True           True                False     daily_star
# 5            True           True                False       ny_times
# 6            True           True                False     daily_star
# 7            True           True                False       ny_times
# 8            True           True                False       ny_times
# 9            True           True                False  dhaka_tribune
# 10          False           True                False  dhaka_tribune
# 11           True          False                False  dhaka_tribune
# 12           True          False                False  dhaka_tribune
# 13           True          False                False  dhaka_tribune
# 14           True          False                False  dhaka_tribune
# 15           True          False                False     daily_star
# 16           True           True                False  dhaka_tribune
# 17           True           True                False       ny_times
# 18          False           True                False       ny_times
# 19           True           True                False     daily_star
# 20           True           True                False     daily_star
# 21           True          False                False     daily_star
# 22           True           True                False     daily_star
# 23           True           True                False       ny_times
# 24           True          False                False  dhaka_tribune
# 25           True           True                False       ny_times
#
#        flood_type                                               text  predict
# 0         cyclone  PRIEST IS HONORED FOR WORK IN ASIA\n1987-08-16...        0
# 1            None  Key Sections of the Paris Communique by the Gr...        0
# 2         cyclone  Date Published:2020-04-13 00:00:00      \nLoca...        1
# 3            None  Date Published:2020-01-18 00:00:00      \nHund...        0
# 4            None  Date Published:2019-08-02 00:00:00      \nDeng...        0
# 5            None  Bangladeshi Asks for Help on Controlling Flood...        1
# 6         cyclone  Date Published:2019-05-03 00:00:00      \nAt l...        1
# 7         monsoon  Bangladesh Flood Toll Up to 680 in Monsoon\n19...        1
# 8         monsoon  In Bangladesh, Too Much Water and Not Enough\n...        1
# 9   river_erosion  Date Published:2019-10-06 00:00:00      \nIn M...        1
# 10        monsoon  Date Published:2019-07-15 00:00:00      \nFloo...        1
# 11           None  Date Published:2020-04-07 00:00:00      \nThe ...        0
# 12           None  Date Published:2019-11-26 00:00:00      \nAll ...        0
# 13           None  Date Published:2019-06-14 00:00:00      \nThe ...        0
# 14           None  Date Published:2020-03-16 00:00:00      \nSult...        0
# 15           None  Date Published:2019-11-08 00:00:00      \nYout...        0
# 16  river_erosion  Date Published:2019-10-11 00:00:00      \nAcco...        1
# 17        cyclone  Death Toll at 500 in Bangladesh Cyclone\n1988-...        1
# 18           None  Death Toll in India After Heavy Floods Is Repo...        1
# 19           None  Date Published:2020-04-18 00:00:00      \nIncl...        0
# 20  river_erosion  Date Published:2019-08-19 00:00:00      \nThe ...        1
# 21           None  Date Published:2019-04-21 00:00:00      \nBoat...        0
# 22  river_erosion  Date Published:2019-08-10 00:00:00      \nEid ...        1
# 23        cyclone  Life in Bangladesh Delta: On the Edge of Disas...        1
# 24           None  Date Published:2020-04-17 00:00:00      \nThe ...        0
# 25        monsoon  IDEAS & TRENDS; Once More, the Earth Visits Di...        1

# %% [markdown]
# ### Classifier Random Forest

# %%
RF_clf_result, RF_result = {},{}

# %%
RF_feature_extract = {
    'CountVect': {
        'classifier_type': 'Count Vectorizer',
        'method': CountVectorizer,
        'params': {
            'tokenizer': word_tokenize,
            'stop_words': 'english'
        }
    },
    'CountVect-min_df5':{
        'base_method': 'CountVect',
        'params':{
            'min_df': 5
        }
    },
    'CountVect-min_df10':{
        'base_method': 'CountVect',
        'params':{
            'min_df': 10
        }
    },
    'CountVect-ngram2':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (2,2)
        }
    },
    'CountVect-ngram3':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (3,3)
        }
    },
    'CountVect-min_df5-ngram2':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (2,2),
            'min_df': 5
        }
    },
    'CountVect-min_df5-ngram3':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (3,3),
            'min_df': 5
        }
    },
    'CountVect-min_df10-ngram2':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (2,2),
            'min_df': 10
        }
    },
    'CountVect-min_df10-ngram3':{
        'base_method': 'CountVect',
        'params':{
            'ngram_range': (3,3),
            'min_df': 10
        }
    },
    'TFIDF': {
        'classifier_type': 'TFIDF',
        'method': TfidfVectorizer,
        'params': {
            'tokenizer': word_tokenize,
            'stop_words': 'english'
        }
    },
    'TFIDF-min_df5':{
        'base_method': 'TFIDF',
        'params':{
            'min_df': 5
        }
    },
    'TFIDF-min_df10':{
        'base_method': 'TFIDF',
        'params':{
            'min_df': 10
        }
    },
}

RF_classifiers = {
    'RandomForest': {
        'classifier_type':'Random Forest ',
        'method': RandomForestClassifier,
    },
}

RF_grid_parameters = {
    'data': ['1:1', '1:2', '1:3', '1:5'],
    'feature_extract': list(RF_feature_extract.keys()),
    'classifier': list(RF_classifiers.keys()),
}
RF_grid = ParameterGrid(RF_grid_parameters)

# %%
override=global_override or False
debug=True
save_results_folder = 'results/'
load_results_folder = 'results/'
if not os.path.isdir(save_results_folder): os.mkdir(save_results_folder)
RF_clf_result, RF_result = run_grid(RF_grid, data, RF_feature_extract, RF_classifiers, RF_clf_result, RF_result, 
                              debug=debug, override=override, save_folder=save_results_folder, 
                             load_folder=load_results_folder, file_prefix='RandomForest-')
# Out:
# loaded result

# %%
parse_result(RF_result)
# Out:
# Data Ratio: 1:1
# | feature_extract           | classifier   |   accuracy | keys                                       |
# |:--------------------------|:-------------|-----------:|:-------------------------------------------|
# | CountVect                 | RandomForest |   0.961538 | 1:1-CountVect-RandomForest                 |
# | CountVect-min_df10        | RandomForest |   0.961538 | 1:1-CountVect-min_df10-RandomForest        |
# | CountVect-min_df10-ngram2 | RandomForest |   0.846154 | 1:1-CountVect-min_df10-ngram2-RandomForest |
# | CountVect-min_df10-ngram3 | RandomForest |   0.769231 | 1:1-CountVect-min_df10-ngram3-RandomForest |
# | CountVect-min_df5         | RandomForest |   0.961538 | 1:1-CountVect-min_df5-RandomForest         |
# | CountVect-min_df5-ngram2  | RandomForest |   0.807692 | 1:1-CountVect-min_df5-ngram2-RandomForest  |
# | CountVect-min_df5-ngram3  | RandomForest |   0.615385 | 1:1-CountVect-min_df5-ngram3-RandomForest  |
# | CountVect-ngram2          | RandomForest |   0.846154 | 1:1-CountVect-ngram2-RandomForest          |
# | CountVect-ngram3          | RandomForest |   0.730769 | 1:1-CountVect-ngram3-RandomForest          |
# | TFIDF                     | RandomForest |   0.961538 | 1:1-TFIDF-RandomForest                     |
# | TFIDF-min_df10            | RandomForest |   0.961538 | 1:1-TFIDF-min_df10-RandomForest            |
# | TFIDF-min_df5             | RandomForest |   0.961538 | 1:1-TFIDF-min_df5-RandomForest             |
#
# Data Ratio: 1:2
# | feature_extract           | classifier   |   accuracy | keys                                       |
# |:--------------------------|:-------------|-----------:|:-------------------------------------------|
# | CountVect                 | RandomForest |   0.684211 | 1:2-CountVect-RandomForest                 |
# | CountVect-min_df10        | RandomForest |   0.684211 | 1:2-CountVect-min_df10-RandomForest        |
# | CountVect-min_df10-ngram2 | RandomForest |   0.868421 | 1:2-CountVect-min_df10-ngram2-RandomForest |
# | CountVect-min_df10-ngram3 | RandomForest |   0.684211 | 1:2-CountVect-min_df10-ngram3-RandomForest |
# | CountVect-min_df5         | RandomForest |   0.763158 | 1:2-CountVect-min_df5-RandomForest         |
# | CountVect-min_df5-ngram2  | RandomForest |   0.842105 | 1:2-CountVect-min_df5-ngram2-RandomForest  |
# | CountVect-min_df5-ngram3  | RandomForest |   0.763158 | 1:2-CountVect-min_df5-ngram3-RandomForest  |
# | CountVect-ngram2          | RandomForest |   0.842105 | 1:2-CountVect-ngram2-RandomForest          |
# | CountVect-ngram3          | RandomForest |   0.710526 | 1:2-CountVect-ngram3-RandomForest          |
# | TFIDF                     | RandomForest |   0.921053 | 1:2-TFIDF-RandomForest                     |
# | TFIDF-min_df10            | RandomForest |   0.921053 | 1:2-TFIDF-min_df10-RandomForest            |
# | TFIDF-min_df5             | RandomForest |   0.894737 | 1:2-TFIDF-min_df5-RandomForest             |
#
# Data Ratio: 1:3
# | feature_extract           | classifier   |   accuracy | keys                                       |
# |:--------------------------|:-------------|-----------:|:-------------------------------------------|
# | CountVect                 | RandomForest |   0.764706 | 1:3-CountVect-RandomForest                 |
# | CountVect-min_df10        | RandomForest |   0.784314 | 1:3-CountVect-min_df10-RandomForest        |
# | CountVect-min_df10-ngram2 | RandomForest |   0.882353 | 1:3-CountVect-min_df10-ngram2-RandomForest |
# | CountVect-min_df10-ngram3 | RandomForest |   0.764706 | 1:3-CountVect-min_df10-ngram3-RandomForest |
# | CountVect-min_df5         | RandomForest |   0.803922 | 1:3-CountVect-min_df5-RandomForest         |
# | CountVect-min_df5-ngram2  | RandomForest |   0.843137 | 1:3-CountVect-min_df5-ngram2-RandomForest  |
# | CountVect-min_df5-ngram3  | RandomForest |   0.843137 | 1:3-CountVect-min_df5-ngram3-RandomForest  |
# | CountVect-ngram2          | RandomForest |   0.862745 | 1:3-CountVect-ngram2-RandomForest          |
# | CountVect-ngram3          | RandomForest |   0.764706 | 1:3-CountVect-ngram3-RandomForest          |
# | TFIDF                     | RandomForest |   0.941176 | 1:3-TFIDF-RandomForest                     |
# | TFIDF-min_df10            | RandomForest |   0.921569 | 1:3-TFIDF-min_df10-RandomForest            |
# | TFIDF-min_df5             | RandomForest |   0.960784 | 1:3-TFIDF-min_df5-RandomForest             |
#
# Data Ratio: 1:5
# | feature_extract           | classifier   |   accuracy | keys                                       |
# |:--------------------------|:-------------|-----------:|:-------------------------------------------|
# | CountVect                 | RandomForest |   0.763158 | 1:5-CountVect-RandomForest                 |
# | CountVect-min_df10        | RandomForest |   0.763158 | 1:5-CountVect-min_df10-RandomForest        |
# | CountVect-min_df10-ngram2 | RandomForest |   0.815789 | 1:5-CountVect-min_df10-ngram2-RandomForest |
# | CountVect-min_df10-ngram3 | RandomForest |   0.763158 | 1:5-CountVect-min_df10-ngram3-RandomForest |
# | CountVect-min_df5         | RandomForest |   0.815789 | 1:5-CountVect-min_df5-RandomForest         |
# | CountVect-min_df5-ngram2  | RandomForest |   0.842105 | 1:5-CountVect-min_df5-ngram2-RandomForest  |
# | CountVect-min_df5-ngram3  | RandomForest |   0.802632 | 1:5-CountVect-min_df5-ngram3-RandomForest  |
# | CountVect-ngram2          | RandomForest |   0.828947 | 1:5-CountVect-ngram2-RandomForest          |
# | CountVect-ngram3          | RandomForest |   0.75     | 1:5-CountVect-ngram3-RandomForest          |
# | TFIDF                     | RandomForest |   0.855263 | 1:5-TFIDF-RandomForest                     |
# | TFIDF-min_df10            | RandomForest |   0.881579 | 1:5-TFIDF-min_df10-RandomForest            |
# | TFIDF-min_df5             | RandomForest |   0.894737 | 1:5-TFIDF-min_df5-RandomForest             |

# %%
parse_result(RF_result, 0.92)
# Out:
# Data Ratio: 1:1
# | feature_extract    | classifier   |   accuracy | keys                                |
# |:-------------------|:-------------|-----------:|:------------------------------------|
# | CountVect          | RandomForest |   0.961538 | 1:1-CountVect-RandomForest          |
# | CountVect-min_df10 | RandomForest |   0.961538 | 1:1-CountVect-min_df10-RandomForest |
# | CountVect-min_df5  | RandomForest |   0.961538 | 1:1-CountVect-min_df5-RandomForest  |
# | TFIDF              | RandomForest |   0.961538 | 1:1-TFIDF-RandomForest              |
# | TFIDF-min_df10     | RandomForest |   0.961538 | 1:1-TFIDF-min_df10-RandomForest     |
# | TFIDF-min_df5      | RandomForest |   0.961538 | 1:1-TFIDF-min_df5-RandomForest      |
#
# Data Ratio: 1:2
# | feature_extract   | classifier   |   accuracy | keys                            |
# |:------------------|:-------------|-----------:|:--------------------------------|
# | TFIDF             | RandomForest |   0.921053 | 1:2-TFIDF-RandomForest          |
# | TFIDF-min_df10    | RandomForest |   0.921053 | 1:2-TFIDF-min_df10-RandomForest |
#
# Data Ratio: 1:3
# | feature_extract   | classifier   |   accuracy | keys                            |
# |:------------------|:-------------|-----------:|:--------------------------------|
# | TFIDF             | RandomForest |   0.941176 | 1:3-TFIDF-RandomForest          |
# | TFIDF-min_df10    | RandomForest |   0.921569 | 1:3-TFIDF-min_df10-RandomForest |
# | TFIDF-min_df5     | RandomForest |   0.960784 | 1:3-TFIDF-min_df5-RandomForest  |
#
# Data Ratio: 1:5
# | feature_extract   | classifier   | accuracy   | keys   |
# |-------------------|--------------|------------|--------|
